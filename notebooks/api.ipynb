# %%
from data_collection.api_wrapper.api_wrapper_factory import create_api_wrapper

api = create_api_wrapper(version=1)
results = api.get_tweets_by_keywords(keywords=['intj', 'entp'])

# %%
results
# Out:
# [Status(_api=<tweepy.api.API object at 0x1037cd6d0>, _json={'created_at': 'Sun Jan 30 18:51:36 +0000 2022', 'id': 1487861070450544641, 'id_str': '1487861070450544641', 'text': '@ONLYM1ND Entp ciktim', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ONLYM1ND', 'name': 'sherL 🔥 | criminal minds s.2', 'id': 1408136143523266561, 'id_str': '1408136143523266561', 'indices': [0, 9]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1487791452595888131, 'in_reply_to_status_id_str': '1487791452595888131', 'in_reply_to_user_id': 1408136143523266561, 'in_reply_to_user_id_str': '1408136143523266561', 'in_reply_to_screen_name': 'ONLYM1ND', 'user': {'id': 1372821132617920516, 'id_str': '1372821132617920516', 'name': "›Scarlett|Lus' day!!‹", 'screen_name': 'NE0NKNIGHTS', 'location': 'Camp Half-Blo
# ...
